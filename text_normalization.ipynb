# %%
import sys
import re
import string
from itertools import chain

import pandas as pd
import nltk
from nltk.corpus import wordnet, stopwords
from nltk.tokenize import(
    word_tokenize,
    wordpunct_tokenize,
    WhitespaceTokenizer,
    RegexpTokenizer,
    sent_tokenize
)

# %%
print(sys.version)
# Out:
# 3.11.9 | packaged by conda-forge | (main, Apr 19 2024, 18:36:13) [GCC 12.3.0]

# %%
# the below code will need to be run if first time using nltk
# downloads all nltk data used for functionality
# nltk.download("all")

# %% [markdown]
# Text normalization is the process of making text uniform. It entails tokenization, removal of stopwords, punction, lemmatization/stemming, etc. **The level of text normalization is task dependent**: in some tasks, less normalization is better.

# %% [markdown]
# # Tokenization

# %%
text = """
Dr. Smith, a renowned historian with a Ph.D. from Harvard, said, "The 20th century was transformative; it's undeniable." Mr. Johnson, CEO of TechInnovations, agrees: "In the 1990s, technology's impact began accelerating." They were discussing this over email (contact@techinnovations.com), emphasizing the importance of innovation. Meanwhile, Ms. Davis, an expert in ancient cultures, found artifacts worth $2,500,000 in Italy. Interestingly, these artifacts date back to 300 B.C. Visit our website for more: http://www.historyartifacts.com. Did you know? The average temperature in New York has risen by 1.5°C since 1950. This fact, among others, was highlighted in the recent study published by the Environmental Research Institute; however, the implications are yet to be fully understood...
"""

# %% [markdown]
# Using NLTK's recommended word tokenizer. Under the hood, this function first applies sentence tokenization, then applies word tokenization on those sentences.

# %%
tokens_1 = word_tokenize(text)
print(*tokens_1, sep="\n")
# Out:
# Dr.
# Smith
# ,
# a
# renowned
# historian
# with
# a
# Ph.D.
# from
# Harvard
# ,
# said
# ,
# ``
# The
# 20th
# century
# was
# transformative
# ;
# it
# 's
# undeniable
# .
# ''
# Mr.
# Johnson
# ,
# CEO
# of
# TechInnovations
# ,
# agrees
# :
# ``
# In
# the
# 1990s
# ,
# technology
# 's
# impact
# began
# accelerating
# .
# ''
# They
# were
# discussing
# this
# over
# email
# (
# contact
# @
# techinnovations.com
# )
# ,
# emphasizing
# the
# importance
# of
# innovation
# .
# Meanwhile
# ,
# Ms.
# Davis
# ,
# an
# expert
# in
# ancient
# cultures
# ,
# found
# artifacts
# worth
# $
# 2,500,000
# in
# Italy
# .
# Interestingly
# ,
# these
# artifacts
# date
# back
# to
# 300
# B.C
# .
# Visit
# our
# website
# for
# more
# :
# http
# :
# //www.historyartifacts.com
# .
# Did
# you
# know
# ?
# The
# average
# temperature
# in
# New
# York
# has
# risen
# by
# 1.5°C
# since
# 1950
# .
# This
# fact
# ,
# among
# others
# ,
# was
# highlighted
# in
# the
# recent
# study
# published
# by
# the
# Environmental
# Research
# Institute
# ;
# however
# ,
# the
# implications
# are
# yet
# to
# be
# fully
# understood
# ...

# %% [markdown]
# A simpler tokenizer thats regex-based which splits text on punctuation and whitespace.

# %%
tokens_2 = wordpunct_tokenize(text)

print(*tokens_2, sep="\n")
# Out:
# Dr
# .
# Smith
# ,
# a
# renowned
# historian
# with
# a
# Ph
# .
# D
# .
# from
# Harvard
# ,
# said
# ,
# "
# The
# 20th
# century
# was
# transformative
# ;
# it
# '
# s
# undeniable
# ."
# Mr
# .
# Johnson
# ,
# CEO
# of
# TechInnovations
# ,
# agrees
# :
# "
# In
# the
# 1990s
# ,
# technology
# '
# s
# impact
# began
# accelerating
# ."
# They
# were
# discussing
# this
# over
# email
# (
# contact
# @
# techinnovations
# .
# com
# ),
# emphasizing
# the
# importance
# of
# innovation
# .
# Meanwhile
# ,
# Ms
# .
# Davis
# ,
# an
# expert
# in
# ancient
# cultures
# ,
# found
# artifacts
# worth
# $
# 2
# ,
# 500
# ,
# 000
# in
# Italy
# .
# Interestingly
# ,
# these
# artifacts
# date
# back
# to
# 300
# B
# .
# C
# .
# Visit
# our
# website
# for
# more
# :
# http
# ://
# www
# .
# historyartifacts
# .
# com
# .
# Did
# you
# know
# ?
# The
# average
# temperature
# in
# New
# York
# has
# risen
# by
# 1
# .
# 5
# °
# C
# since
# 1950
# .
# This
# fact
# ,
# among
# others
# ,
# was
# highlighted
# in
# the
# recent
# study
# published
# by
# the
# Environmental
# Research
# Institute
# ;
# however
# ,
# the
# implications
# are
# yet
# to
# be
# fully
# understood
# ...

# %% [markdown]
# An even simpler tokenizer that tokenizes just on white space. This does the same thing as built-in `split()` method. In fact, NLTK recommends doing just that:
#
# >In general, users should use the string split() method instead.

# %%
w_space_tokenizer = WhitespaceTokenizer()
tokens_3 = w_space_tokenizer.tokenize(text)

print(*tokens_3, sep="\n")
# Out:
# Dr.
# Smith,
# a
# renowned
# historian
# with
# a
# Ph.D.
# from
# Harvard,
# said,
# "The
# 20th
# century
# was
# transformative;
# it's
# undeniable."
# Mr.
# Johnson,
# CEO
# of
# TechInnovations,
# agrees:
# "In
# the
# 1990s,
# technology's
# impact
# began
# accelerating."
# They
# were
# discussing
# this
# over
# email
# (contact@techinnovations.com),
# emphasizing
# the
# importance
# of
# innovation.
# Meanwhile,
# Ms.
# Davis,
# an
# expert
# in
# ancient
# cultures,
# found
# artifacts
# worth
# $2,500,000
# in
# Italy.
# Interestingly,
# these
# artifacts
# date
# back
# to
# 300
# B.C.
# Visit
# our
# website
# for
# more:
# http://www.historyartifacts.com.
# Did
# you
# know?
# The
# average
# temperature
# in
# New
# York
# has
# risen
# by
# 1.5°C
# since
# 1950.
# This
# fact,
# among
# others,
# was
# highlighted
# in
# the
# recent
# study
# published
# by
# the
# Environmental
# Research
# Institute;
# however,
# the
# implications
# are
# yet
# to
# be
# fully
# understood...

# %% [markdown]
# We can even write our own tokenzer if the occassion arises:

# %%
# below pattern is broken, only for demo purposes ()
pattern =  """
(?:[A-Z]\.)+               # all caps abbreviations 
| \w+(?:-\w+)*             # hypenated words
| \$?\d{1,3}(?:,\d{3})*(?:\.\d+)?%?  # monetary amounts $2,500,000 or 82%
| \.{3}                    # ellipsis
| [.,;"'?():_`-]           # punctuation characters
| \w+@\w+\.\w{2,3}         # emails
| http[s]?://\S+           # urls
"""

regex_tokenizer = RegexpTokenizer(pattern, flags=re.VERBOSE)
tokens_4 = regex_tokenizer.tokenize(text)

print(*tokens_4, sep="\n")
# Out:
# Dr
# .
# Smith
# ,
# a
# renowned
# historian
# with
# a
# Ph
# .
# D.
# from
# Harvard
# ,
# said
# ,
# "
# The
# 20th
# century
# was
# transformative
# ;
# it
# '
# s
# undeniable
# .
# "
# Mr
# .
# Johnson
# ,
# CEO
# of
# TechInnovations
# ,
# agrees
# :
# "
# In
# the
# 1990s
# ,
# technology
# '
# s
# impact
# began
# accelerating
# .
# "
# They
# were
# discussing
# this
# over
# email
# (
# contact
# techinnovations
# .
# com
# )
# ,
# emphasizing
# the
# importance
# of
# innovation
# .
# Meanwhile
# ,
# Ms
# .
# Davis
# ,
# an
# expert
# in
# ancient
# cultures
# ,
# found
# artifacts
# worth
# $2,500,000
# in
# Italy
# .
# Interestingly
# ,
# these
# artifacts
# date
# back
# to
# 300
# B.C.
# Visit
# our
# website
# for
# more
# :
# http
# :
# www
# .
# historyartifacts
# .
# com
# .
# Did
# you
# know
# ?
# The
# average
# temperature
# in
# New
# York
# has
# risen
# by
# 1
# .
# 5
# C
# since
# 1950
# .
# This
# fact
# ,
# among
# others
# ,
# was
# highlighted
# in
# the
# recent
# study
# published
# by
# the
# Environmental
# Research
# Institute
# ;
# however
# ,
# the
# implications
# are
# yet
# to
# be
# fully
# understood
# ...

# %% [markdown]
# We can also tokenize into sentences, also referred to sentence segmentation. This very useful in many occassions. For example, if we have to chunk text for processing, we may want to chunktext in a way that doesn't split sentences.

# %%
sentences = sent_tokenize(text)

print(*sentences, sep="\n")
# Out:
# Dr. Smith, a renowned historian with a Ph.D. from Harvard, said, "The 20th century was transformative; it's undeniable."
# Mr. Johnson, CEO of TechInnovations, agrees: "In the 1990s, technology's impact began accelerating."
# They were discussing this over email (contact@techinnovations.com), emphasizing the importance of innovation.
# Meanwhile, Ms. Davis, an expert in ancient cultures, found artifacts worth $2,500,000 in Italy.
# Interestingly, these artifacts date back to 300 B.C.
# Visit our website for more: http://www.historyartifacts.com.
# Did you know?
# The average temperature in New York has risen by 1.5°C since 1950.
# This fact, among others, was highlighted in the recent study published by the Environmental Research Institute; however, the implications are yet to be fully understood...

# %% [markdown]
# ## Stemming & Lemmatization

# %% [markdown]
# Stemming and lemmatization both try to reduce word inflections but go about it in different ways. Now that we have words (tokens), we can apply these methods.

# %%
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
lemmatizer = nltk.WordNetLemmatizer()

# %%
tokens = word_tokenize(text) # using recommended tokenizer

# %%
df = pd.DataFrame(
    {
        "original": tokens,
        "porter": [porter.stem(token) for token in tokens],
        "lancaster": [lancaster.stem(token) for token in tokens],
        "lemmas": [lemmatizer.lemmatize(token) for token in tokens]
    }
)

# %% [markdown]
# For the below output, does lemmatization perform as expected?

# %%
with pd.option_context("display.max_rows", 200):
    display(df)
# Out:
#                        original                      porter  \
# 0                           Dr.                         dr.
# 1                         Smith                       smith
# 2                             ,                           ,
# 3                             a                           a
# 4                      renowned                      renown
# 5                     historian                   historian
# 6                          with                        with
# 7                             a                           a
# 8                         Ph.D.                       ph.d.
# 9                          from                        from
# 10                      Harvard                     harvard
# 11                            ,                           ,
# 12                         said                        said
# 13                            ,                           ,
# 14                           ``                          ``
# 15                          The                         the
# 16                         20th                        20th
# 17                      century                     centuri
# 18                          was                          wa
# 19               transformative                   transform
# 20                            ;                           ;
# 21                           it                          it
# 22                           's                          's
# 23                   undeniable                      undeni
# 24                            .                           .
# 25                           ''                          ''
# 26                          Mr.                         mr.
# 27                      Johnson                     johnson
# 28                            ,                           ,
# 29                          CEO                         ceo
# 30                           of                          of
# 31              TechInnovations                   techinnov
# 32                            ,                           ,
# 33                       agrees                        agre
# 34                            :                           :
# 35                           ``                          ``
# 36                           In                          in
# 37                          the                         the
# 38                        1990s                        1990
# 39                            ,                           ,
# 40                   technology                   technolog
# 41                           's                          's
# 42                       impact                      impact
# 43                        began                       began
# 44                 accelerating                     acceler
# 45                            .                           .
# 46                           ''                          ''
# 47                         They                        they
# 48                         were                        were
# 49                   discussing                     discuss
# 50                         this                         thi
# 51                         over                        over
# 52                        email                       email
# 53                            (                           (
# 54                      contact                     contact
# 55                            @                           @
# 56          techinnovations.com         techinnovations.com
# 57                            )                           )
# 58                            ,                           ,
# 59                  emphasizing                      emphas
# 60                          the                         the
# 61                   importance                      import
# 62                           of                          of
# 63                   innovation                       innov
# 64                            .                           .
# 65                    Meanwhile                    meanwhil
# 66                            ,                           ,
# 67                          Ms.                         ms.
# 68                        Davis                        davi
# 69                            ,                           ,
# 70                           an                          an
# 71                       expert                      expert
# 72                           in                          in
# 73                      ancient                     ancient
# 74                     cultures                      cultur
# 75                            ,                           ,
# 76                        found                       found
# 77                    artifacts                    artifact
# 78                        worth                       worth
# 79                            $                           $
# 80                    2,500,000                   2,500,000
# 81                           in                          in
# 82                        Italy                       itali
# 83                            .                           .
# 84                Interestingly               interestingli
# 85                            ,                           ,
# 86                        these                       these
# 87                    artifacts                    artifact
# 88                         date                        date
# 89                         back                        back
# 90                           to                          to
# 91                          300                         300
# 92                          B.C                         b.c
# 93                            .                           .
# 94                        Visit                       visit
# 95                          our                         our
# 96                      website                      websit
# 97                          for                         for
# 98                         more                        more
# 99                            :                           :
# 100                        http                        http
# 101                           :                           :
# 102  //www.historyartifacts.com  //www.historyartifacts.com
# 103                           .                           .
# 104                         Did                         did
# 105                         you                         you
# 106                        know                        know
# 107                           ?                           ?
# 108                         The                         the
# 109                     average                      averag
# 110                 temperature                  temperatur
# 111                          in                          in
# 112                         New                         new
# 113                        York                        york
# 114                         has                          ha
# 115                       risen                       risen
# 116                          by                          by
# 117                       1.5°C                       1.5°c
# 118                       since                        sinc
# 119                        1950                        1950
# 120                           .                           .
# 121                        This                         thi
# 122                        fact                        fact
# 123                           ,                           ,
# 124                       among                       among
# 125                      others                       other
# 126                           ,                           ,
# 127                         was                          wa
# 128                 highlighted                   highlight
# 129                          in                          in
# 130                         the                         the
# 131                      recent                      recent
# 132                       study                       studi
# 133                   published                     publish
# 134                          by                          by
# 135                         the                         the
# 136               Environmental                 environment
# 137                    Research                    research
# 138                   Institute                    institut
# 139                           ;                           ;
# 140                     however                       howev
# 141                           ,                           ,
# 142                         the                         the
# 143                implications                      implic
# 144                         are                         are
# 145                         yet                         yet
# 146                          to                          to
# 147                          be                          be
# 148                       fully                       fulli
# 149                  understood                  understood
# 150                         ...                         ...
#
#                       lancaster                      lemmas
# 0                           dr.                         Dr.
# 1                           smi                       Smith
# 2                             ,                           ,
# 3                             a                           a
# 4                        renown                    renowned
# 5                          hist                   historian
# 6                          with                        with
# 7                             a                           a
# 8                         ph.d.                       Ph.D.
# 9                          from                        from
# 10                      harvard                     Harvard
# 11                            ,                           ,
# 12                         said                        said
# 13                            ,                           ,
# 14                           ``                          ``
# 15                          the                         The
# 16                         20th                        20th
# 17                      century                     century
# 18                          was                          wa
# 19                    transform              transformative
# 20                            ;                           ;
# 21                           it                          it
# 22                           's                          's
# 23                       undeny                  undeniable
# 24                            .                           .
# 25                           ''                          ''
# 26                          mr.                         Mr.
# 27                      johnson                     Johnson
# 28                            ,                           ,
# 29                          ceo                         CEO
# 30                           of                          of
# 31                    techinnov             TechInnovations
# 32                            ,                           ,
# 33                          agr                      agrees
# 34                            :                           :
# 35                           ``                          ``
# 36                           in                          In
# 37                          the                         the
# 38                        1990s                       1990s
# 39                            ,                           ,
# 40                    technolog                  technology
# 41                           's                          's
# 42                       impact                      impact
# 43                          beg                       began
# 44                        accel                accelerating
# 45                            .                           .
# 46                           ''                          ''
# 47                         they                        They
# 48                          wer                        were
# 49                      discuss                  discussing
# 50                          thi                        this
# 51                           ov                        over
# 52                        email                       email
# 53                            (                           (
# 54                      contact                     contact
# 55                            @                           @
# 56          techinnovations.com         techinnovations.com
# 57                            )                           )
# 58                            ,                           ,
# 59                       emphas                 emphasizing
# 60                          the                         the
# 61                       import                  importance
# 62                           of                          of
# 63                        innov                  innovation
# 64                            .                           .
# 65                     meanwhil                   Meanwhile
# 66                            ,                           ,
# 67                          ms.                         Ms.
# 68                          dav                       Davis
# 69                            ,                           ,
# 70                           an                          an
# 71                       expert                      expert
# 72                           in                          in
# 73                          ant                     ancient
# 74                         cult                     culture
# 75                            ,                           ,
# 76                        found                       found
# 77                     artifact                    artifact
# 78                          wor                       worth
# 79                            $                           $
# 80                    2,500,000                   2,500,000
# 81                           in                          in
# 82                          ita                       Italy
# 83                            .                           .
# 84                     interest               Interestingly
# 85                            ,                           ,
# 86                         thes                       these
# 87                     artifact                    artifact
# 88                          dat                        date
# 89                         back                        back
# 90                           to                          to
# 91                          300                         300
# 92                          b.c                         B.C
# 93                            .                           .
# 94                        visit                       Visit
# 95                          our                         our
# 96                       websit                     website
# 97                          for                         for
# 98                          mor                        more
# 99                            :                           :
# 100                        http                        http
# 101                           :                           :
# 102  //www.historyartifacts.com  //www.historyartifacts.com
# 103                           .                           .
# 104                         did                         Did
# 105                         you                         you
# 106                        know                        know
# 107                           ?                           ?
# 108                         the                         The
# 109                          av                     average
# 110                        temp                 temperature
# 111                          in                          in
# 112                         new                         New
# 113                        york                        York
# 114                         has                          ha
# 115                         ris                       risen
# 116                          by                          by
# 117                       1.5°c                       1.5°C
# 118                        sint                       since
# 119                        1950                        1950
# 120                           .                           .
# 121                         thi                        This
# 122                        fact                        fact
# 123                           ,                           ,
# 124                       among                       among
# 125                         oth                      others
# 126                           ,                           ,
# 127                         was                          wa
# 128                   highlight                 highlighted
# 129                          in                          in
# 130                         the                         the
# 131                         rec                      recent
# 132                       study                       study
# 133                        publ                   published
# 134                          by                          by
# 135                         the                         the
# 136                     environ               Environmental
# 137                    research                    Research
# 138                    institut                   Institute
# 139                           ;                           ;
# 140                       howev                     however
# 141                           ,                           ,
# 142                         the                         the
# 143                       imply                 implication
# 144                          ar                         are
# 145                         yet                         yet
# 146                          to                          to
# 147                          be                          be
# 148                         ful                       fully
# 149                  understood                  understood
# 150                         ...                         ...

# %% [markdown]
# Lemmatization seems to be underperforming. Reason is because NLTK implementation of lemmatizer uses the parts of speech tag of word, which has to be manually provided

# %%
pos_tags = nltk.pos_tag(tokens) # returns a list of (token, tag) tuples


def get_wordnet_pos(treebank_tag, skip_value="n"):
    """Converts treebank tags to WordNet tags."""
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return skip_value
    

pos_tags_wordnet = [(token, get_wordnet_pos(tag)) for token, tag in pos_tags]

# %% [markdown]
# With the tags known known, we can apply lemmatization again

# %%
df = pd.DataFrame(
    {
        "original": tokens,
        "porter": [porter.stem(token) for token in tokens],
        "lancaster": [lancaster.stem(token) for token in tokens],
        "lemmas": [lemmatizer.lemmatize(token) for token in tokens],
        "lemmas_improved": [lemmatizer.lemmatize(token, pos) for token, pos in pos_tags_wordnet]
    }
)

# %%
with pd.option_context("display.max_rows", 200):
    display(df)
# Out:
#                        original                      porter  \
# 0                           Dr.                         dr.
# 1                         Smith                       smith
# 2                             ,                           ,
# 3                             a                           a
# 4                      renowned                      renown
# 5                     historian                   historian
# 6                          with                        with
# 7                             a                           a
# 8                         Ph.D.                       ph.d.
# 9                          from                        from
# 10                      Harvard                     harvard
# 11                            ,                           ,
# 12                         said                        said
# 13                            ,                           ,
# 14                           ``                          ``
# 15                          The                         the
# 16                         20th                        20th
# 17                      century                     centuri
# 18                          was                          wa
# 19               transformative                   transform
# 20                            ;                           ;
# 21                           it                          it
# 22                           's                          's
# 23                   undeniable                      undeni
# 24                            .                           .
# 25                           ''                          ''
# 26                          Mr.                         mr.
# 27                      Johnson                     johnson
# 28                            ,                           ,
# 29                          CEO                         ceo
# 30                           of                          of
# 31              TechInnovations                   techinnov
# 32                            ,                           ,
# 33                       agrees                        agre
# 34                            :                           :
# 35                           ``                          ``
# 36                           In                          in
# 37                          the                         the
# 38                        1990s                        1990
# 39                            ,                           ,
# 40                   technology                   technolog
# 41                           's                          's
# 42                       impact                      impact
# 43                        began                       began
# 44                 accelerating                     acceler
# 45                            .                           .
# 46                           ''                          ''
# 47                         They                        they
# 48                         were                        were
# 49                   discussing                     discuss
# 50                         this                         thi
# 51                         over                        over
# 52                        email                       email
# 53                            (                           (
# 54                      contact                     contact
# 55                            @                           @
# 56          techinnovations.com         techinnovations.com
# 57                            )                           )
# 58                            ,                           ,
# 59                  emphasizing                      emphas
# 60                          the                         the
# 61                   importance                      import
# 62                           of                          of
# 63                   innovation                       innov
# 64                            .                           .
# 65                    Meanwhile                    meanwhil
# 66                            ,                           ,
# 67                          Ms.                         ms.
# 68                        Davis                        davi
# 69                            ,                           ,
# 70                           an                          an
# 71                       expert                      expert
# 72                           in                          in
# 73                      ancient                     ancient
# 74                     cultures                      cultur
# 75                            ,                           ,
# 76                        found                       found
# 77                    artifacts                    artifact
# 78                        worth                       worth
# 79                            $                           $
# 80                    2,500,000                   2,500,000
# 81                           in                          in
# 82                        Italy                       itali
# 83                            .                           .
# 84                Interestingly               interestingli
# 85                            ,                           ,
# 86                        these                       these
# 87                    artifacts                    artifact
# 88                         date                        date
# 89                         back                        back
# 90                           to                          to
# 91                          300                         300
# 92                          B.C                         b.c
# 93                            .                           .
# 94                        Visit                       visit
# 95                          our                         our
# 96                      website                      websit
# 97                          for                         for
# 98                         more                        more
# 99                            :                           :
# 100                        http                        http
# 101                           :                           :
# 102  //www.historyartifacts.com  //www.historyartifacts.com
# 103                           .                           .
# 104                         Did                         did
# 105                         you                         you
# 106                        know                        know
# 107                           ?                           ?
# 108                         The                         the
# 109                     average                      averag
# 110                 temperature                  temperatur
# 111                          in                          in
# 112                         New                         new
# 113                        York                        york
# 114                         has                          ha
# 115                       risen                       risen
# 116                          by                          by
# 117                       1.5°C                       1.5°c
# 118                       since                        sinc
# 119                        1950                        1950
# 120                           .                           .
# 121                        This                         thi
# 122                        fact                        fact
# 123                           ,                           ,
# 124                       among                       among
# 125                      others                       other
# 126                           ,                           ,
# 127                         was                          wa
# 128                 highlighted                   highlight
# 129                          in                          in
# 130                         the                         the
# 131                      recent                      recent
# 132                       study                       studi
# 133                   published                     publish
# 134                          by                          by
# 135                         the                         the
# 136               Environmental                 environment
# 137                    Research                    research
# 138                   Institute                    institut
# 139                           ;                           ;
# 140                     however                       howev
# 141                           ,                           ,
# 142                         the                         the
# 143                implications                      implic
# 144                         are                         are
# 145                         yet                         yet
# 146                          to                          to
# 147                          be                          be
# 148                       fully                       fulli
# 149                  understood                  understood
# 150                         ...                         ...
#
#                       lancaster                      lemmas  \
# 0                           dr.                         Dr.
# 1                           smi                       Smith
# 2                             ,                           ,
# 3                             a                           a
# 4                        renown                    renowned
# 5                          hist                   historian
# 6                          with                        with
# 7                             a                           a
# 8                         ph.d.                       Ph.D.
# 9                          from                        from
# 10                      harvard                     Harvard
# 11                            ,                           ,
# 12                         said                        said
# 13                            ,                           ,
# 14                           ``                          ``
# 15                          the                         The
# 16                         20th                        20th
# 17                      century                     century
# 18                          was                          wa
# 19                    transform              transformative
# 20                            ;                           ;
# 21                           it                          it
# 22                           's                          's
# 23                       undeny                  undeniable
# 24                            .                           .
# 25                           ''                          ''
# 26                          mr.                         Mr.
# 27                      johnson                     Johnson
# 28                            ,                           ,
# 29                          ceo                         CEO
# 30                           of                          of
# 31                    techinnov             TechInnovations
# 32                            ,                           ,
# 33                          agr                      agrees
# 34                            :                           :
# 35                           ``                          ``
# 36                           in                          In
# 37                          the                         the
# 38                        1990s                       1990s
# 39                            ,                           ,
# 40                    technolog                  technology
# 41                           's                          's
# 42                       impact                      impact
# 43                          beg                       began
# 44                        accel                accelerating
# 45                            .                           .
# 46                           ''                          ''
# 47                         they                        They
# 48                          wer                        were
# 49                      discuss                  discussing
# 50                          thi                        this
# 51                           ov                        over
# 52                        email                       email
# 53                            (                           (
# 54                      contact                     contact
# 55                            @                           @
# 56          techinnovations.com         techinnovations.com
# 57                            )                           )
# 58                            ,                           ,
# 59                       emphas                 emphasizing
# 60                          the                         the
# 61                       import                  importance
# 62                           of                          of
# 63                        innov                  innovation
# 64                            .                           .
# 65                     meanwhil                   Meanwhile
# 66                            ,                           ,
# 67                          ms.                         Ms.
# 68                          dav                       Davis
# 69                            ,                           ,
# 70                           an                          an
# 71                       expert                      expert
# 72                           in                          in
# 73                          ant                     ancient
# 74                         cult                     culture
# 75                            ,                           ,
# 76                        found                       found
# 77                     artifact                    artifact
# 78                          wor                       worth
# 79                            $                           $
# 80                    2,500,000                   2,500,000
# 81                           in                          in
# 82                          ita                       Italy
# 83                            .                           .
# 84                     interest               Interestingly
# 85                            ,                           ,
# 86                         thes                       these
# 87                     artifact                    artifact
# 88                          dat                        date
# 89                         back                        back
# 90                           to                          to
# 91                          300                         300
# 92                          b.c                         B.C
# 93                            .                           .
# 94                        visit                       Visit
# 95                          our                         our
# 96                       websit                     website
# 97                          for                         for
# 98                          mor                        more
# 99                            :                           :
# 100                        http                        http
# 101                           :                           :
# 102  //www.historyartifacts.com  //www.historyartifacts.com
# 103                           .                           .
# 104                         did                         Did
# 105                         you                         you
# 106                        know                        know
# 107                           ?                           ?
# 108                         the                         The
# 109                          av                     average
# 110                        temp                 temperature
# 111                          in                          in
# 112                         new                         New
# 113                        york                        York
# 114                         has                          ha
# 115                         ris                       risen
# 116                          by                          by
# 117                       1.5°c                       1.5°C
# 118                        sint                       since
# 119                        1950                        1950
# 120                           .                           .
# 121                         thi                        This
# 122                        fact                        fact
# 123                           ,                           ,
# 124                       among                       among
# 125                         oth                      others
# 126                           ,                           ,
# 127                         was                          wa
# 128                   highlight                 highlighted
# 129                          in                          in
# 130                         the                         the
# 131                         rec                      recent
# 132                       study                       study
# 133                        publ                   published
# 134                          by                          by
# 135                         the                         the
# 136                     environ               Environmental
# 137                    research                    Research
# 138                    institut                   Institute
# 139                           ;                           ;
# 140                       howev                     however
# 141                           ,                           ,
# 142                         the                         the
# 143                       imply                 implication
# 144                          ar                         are
# 145                         yet                         yet
# 146                          to                          to
# 147                          be                          be
# 148                         ful                       fully
# 149                  understood                  understood
# 150                         ...                         ...
#
#                 lemmas_improved
# 0                           Dr.
# 1                         Smith
# 2                             ,
# 3                             a
# 4                      renowned
# 5                     historian
# 6                          with
# 7                             a
# 8                         Ph.D.
# 9                          from
# 10                      Harvard
# 11                            ,
# 12                          say
# 13                            ,
# 14                           ``
# 15                          The
# 16                         20th
# 17                      century
# 18                           be
# 19               transformative
# 20                            ;
# 21                           it
# 22                           's
# 23                   undeniable
# 24                            .
# 25                           ''
# 26                          Mr.
# 27                      Johnson
# 28                            ,
# 29                          CEO
# 30                           of
# 31              TechInnovations
# 32                            ,
# 33                        agree
# 34                            :
# 35                           ``
# 36                           In
# 37                          the
# 38                        1990s
# 39                            ,
# 40                   technology
# 41                           's
# 42                       impact
# 43                        begin
# 44                   accelerate
# 45                            .
# 46                           ''
# 47                         They
# 48                           be
# 49                      discuss
# 50                         this
# 51                         over
# 52                        email
# 53                            (
# 54                      contact
# 55                            @
# 56          techinnovations.com
# 57                            )
# 58                            ,
# 59                    emphasize
# 60                          the
# 61                   importance
# 62                           of
# 63                   innovation
# 64                            .
# 65                    Meanwhile
# 66                            ,
# 67                          Ms.
# 68                        Davis
# 69                            ,
# 70                           an
# 71                       expert
# 72                           in
# 73                      ancient
# 74                      culture
# 75                            ,
# 76                         find
# 77                     artifact
# 78                        worth
# 79                            $
# 80                    2,500,000
# 81                           in
# 82                        Italy
# 83                            .
# 84                Interestingly
# 85                            ,
# 86                        these
# 87                     artifact
# 88                         date
# 89                         back
# 90                           to
# 91                          300
# 92                          B.C
# 93                            .
# 94                        Visit
# 95                          our
# 96                      website
# 97                          for
# 98                         more
# 99                            :
# 100                        http
# 101                           :
# 102  //www.historyartifacts.com
# 103                           .
# 104                         Did
# 105                         you
# 106                        know
# 107                           ?
# 108                         The
# 109                     average
# 110                 temperature
# 111                          in
# 112                         New
# 113                        York
# 114                        have
# 115                        rise
# 116                          by
# 117                       1.5°C
# 118                       since
# 119                        1950
# 120                           .
# 121                        This
# 122                        fact
# 123                           ,
# 124                       among
# 125                      others
# 126                           ,
# 127                          be
# 128                   highlight
# 129                          in
# 130                         the
# 131                      recent
# 132                       study
# 133                     publish
# 134                          by
# 135                         the
# 136               Environmental
# 137                    Research
# 138                   Institute
# 139                           ;
# 140                     however
# 141                           ,
# 142                         the
# 143                 implication
# 144                          be
# 145                         yet
# 146                          to
# 147                          be
# 148                       fully
# 149                  understood
# 150                         ...

# %% [markdown]
# ## Stop Words, Case Folding, & Punctuation

# %% [markdown]
# Stopwords are words that can be filtered out of because they contribute little meaning to the text. They are usually the most common words in the language, such as "the", "a", "which", "on", etc. A few notes on stopword removal:
#
# 1. They reduce noise in the data
# 2. They improve efficiency of data processing
# 3. They can increase performance
# 4. Although stopwords lists are common in different libraries, they may differ and can be customized to fit your paritcular application

# %%
# inspecting stopword list
set(stopwords.words("english"))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stop_words = set(stopwords.words("english"))
tokenized_stop_words = set(chain.from_iterable([word_tokenize(word) for word in stop_words])) # why do this?
stop_words = stop_words | tokenized_stop_words

punctuation = set(string.punctuation)
special_punctuation = {"``", "''"}
all_punctuation = punctuation | special_punctuation

# %%
tokens_clean = [token if token.lower() not in stop_words and token not in all_punctuation else "----" for token in tokens]

pos_tags = nltk.pos_tag(tokens_clean) # returns a list of (token, tag) tuples
pos_tags_wordnet = [(token, get_wordnet_pos(tag)) for token, tag in pos_tags]

df = pd.DataFrame(
    {
        "original": tokens,
        "porter": [porter.stem(token) for token in tokens],
        "lancaster": [lancaster.stem(token) for token in tokens],
        "lemmas": [lemmatizer.lemmatize(token) for token in tokens],
        "lemmas_improved": [lemmatizer.lemmatize(token, pos) for token, pos in pos_tags_wordnet]
    }
)

# %%
with pd.option_context("display.max_rows", 200):
    display(df)
# Out:
#                        original                      porter  \
# 0                           Dr.                         dr.
# 1                         Smith                       smith
# 2                             ,                           ,
# 3                             a                           a
# 4                      renowned                      renown
# 5                     historian                   historian
# 6                          with                        with
# 7                             a                           a
# 8                         Ph.D.                       ph.d.
# 9                          from                        from
# 10                      Harvard                     harvard
# 11                            ,                           ,
# 12                         said                        said
# 13                            ,                           ,
# 14                           ``                          ``
# 15                          The                         the
# 16                         20th                        20th
# 17                      century                     centuri
# 18                          was                          wa
# 19               transformative                   transform
# 20                            ;                           ;
# 21                           it                          it
# 22                           's                          's
# 23                   undeniable                      undeni
# 24                            .                           .
# 25                           ''                          ''
# 26                          Mr.                         mr.
# 27                      Johnson                     johnson
# 28                            ,                           ,
# 29                          CEO                         ceo
# 30                           of                          of
# 31              TechInnovations                   techinnov
# 32                            ,                           ,
# 33                       agrees                        agre
# 34                            :                           :
# 35                           ``                          ``
# 36                           In                          in
# 37                          the                         the
# 38                        1990s                        1990
# 39                            ,                           ,
# 40                   technology                   technolog
# 41                           's                          's
# 42                       impact                      impact
# 43                        began                       began
# 44                 accelerating                     acceler
# 45                            .                           .
# 46                           ''                          ''
# 47                         They                        they
# 48                         were                        were
# 49                   discussing                     discuss
# 50                         this                         thi
# 51                         over                        over
# 52                        email                       email
# 53                            (                           (
# 54                      contact                     contact
# 55                            @                           @
# 56          techinnovations.com         techinnovations.com
# 57                            )                           )
# 58                            ,                           ,
# 59                  emphasizing                      emphas
# 60                          the                         the
# 61                   importance                      import
# 62                           of                          of
# 63                   innovation                       innov
# 64                            .                           .
# 65                    Meanwhile                    meanwhil
# 66                            ,                           ,
# 67                          Ms.                         ms.
# 68                        Davis                        davi
# 69                            ,                           ,
# 70                           an                          an
# 71                       expert                      expert
# 72                           in                          in
# 73                      ancient                     ancient
# 74                     cultures                      cultur
# 75                            ,                           ,
# 76                        found                       found
# 77                    artifacts                    artifact
# 78                        worth                       worth
# 79                            $                           $
# 80                    2,500,000                   2,500,000
# 81                           in                          in
# 82                        Italy                       itali
# 83                            .                           .
# 84                Interestingly               interestingli
# 85                            ,                           ,
# 86                        these                       these
# 87                    artifacts                    artifact
# 88                         date                        date
# 89                         back                        back
# 90                           to                          to
# 91                          300                         300
# 92                          B.C                         b.c
# 93                            .                           .
# 94                        Visit                       visit
# 95                          our                         our
# 96                      website                      websit
# 97                          for                         for
# 98                         more                        more
# 99                            :                           :
# 100                        http                        http
# 101                           :                           :
# 102  //www.historyartifacts.com  //www.historyartifacts.com
# 103                           .                           .
# 104                         Did                         did
# 105                         you                         you
# 106                        know                        know
# 107                           ?                           ?
# 108                         The                         the
# 109                     average                      averag
# 110                 temperature                  temperatur
# 111                          in                          in
# 112                         New                         new
# 113                        York                        york
# 114                         has                          ha
# 115                       risen                       risen
# 116                          by                          by
# 117                       1.5°C                       1.5°c
# 118                       since                        sinc
# 119                        1950                        1950
# 120                           .                           .
# 121                        This                         thi
# 122                        fact                        fact
# 123                           ,                           ,
# 124                       among                       among
# 125                      others                       other
# 126                           ,                           ,
# 127                         was                          wa
# 128                 highlighted                   highlight
# 129                          in                          in
# 130                         the                         the
# 131                      recent                      recent
# 132                       study                       studi
# 133                   published                     publish
# 134                          by                          by
# 135                         the                         the
# 136               Environmental                 environment
# 137                    Research                    research
# 138                   Institute                    institut
# 139                           ;                           ;
# 140                     however                       howev
# 141                           ,                           ,
# 142                         the                         the
# 143                implications                      implic
# 144                         are                         are
# 145                         yet                         yet
# 146                          to                          to
# 147                          be                          be
# 148                       fully                       fulli
# 149                  understood                  understood
# 150                         ...                         ...
#
#                       lancaster                      lemmas  \
# 0                           dr.                         Dr.
# 1                           smi                       Smith
# 2                             ,                           ,
# 3                             a                           a
# 4                        renown                    renowned
# 5                          hist                   historian
# 6                          with                        with
# 7                             a                           a
# 8                         ph.d.                       Ph.D.
# 9                          from                        from
# 10                      harvard                     Harvard
# 11                            ,                           ,
# 12                         said                        said
# 13                            ,                           ,
# 14                           ``                          ``
# 15                          the                         The
# 16                         20th                        20th
# 17                      century                     century
# 18                          was                          wa
# 19                    transform              transformative
# 20                            ;                           ;
# 21                           it                          it
# 22                           's                          's
# 23                       undeny                  undeniable
# 24                            .                           .
# 25                           ''                          ''
# 26                          mr.                         Mr.
# 27                      johnson                     Johnson
# 28                            ,                           ,
# 29                          ceo                         CEO
# 30                           of                          of
# 31                    techinnov             TechInnovations
# 32                            ,                           ,
# 33                          agr                      agrees
# 34                            :                           :
# 35                           ``                          ``
# 36                           in                          In
# 37                          the                         the
# 38                        1990s                       1990s
# 39                            ,                           ,
# 40                    technolog                  technology
# 41                           's                          's
# 42                       impact                      impact
# 43                          beg                       began
# 44                        accel                accelerating
# 45                            .                           .
# 46                           ''                          ''
# 47                         they                        They
# 48                          wer                        were
# 49                      discuss                  discussing
# 50                          thi                        this
# 51                           ov                        over
# 52                        email                       email
# 53                            (                           (
# 54                      contact                     contact
# 55                            @                           @
# 56          techinnovations.com         techinnovations.com
# 57                            )                           )
# 58                            ,                           ,
# 59                       emphas                 emphasizing
# 60                          the                         the
# 61                       import                  importance
# 62                           of                          of
# 63                        innov                  innovation
# 64                            .                           .
# 65                     meanwhil                   Meanwhile
# 66                            ,                           ,
# 67                          ms.                         Ms.
# 68                          dav                       Davis
# 69                            ,                           ,
# 70                           an                          an
# 71                       expert                      expert
# 72                           in                          in
# 73                          ant                     ancient
# 74                         cult                     culture
# 75                            ,                           ,
# 76                        found                       found
# 77                     artifact                    artifact
# 78                          wor                       worth
# 79                            $                           $
# 80                    2,500,000                   2,500,000
# 81                           in                          in
# 82                          ita                       Italy
# 83                            .                           .
# 84                     interest               Interestingly
# 85                            ,                           ,
# 86                         thes                       these
# 87                     artifact                    artifact
# 88                          dat                        date
# 89                         back                        back
# 90                           to                          to
# 91                          300                         300
# 92                          b.c                         B.C
# 93                            .                           .
# 94                        visit                       Visit
# 95                          our                         our
# 96                       websit                     website
# 97                          for                         for
# 98                          mor                        more
# 99                            :                           :
# 100                        http                        http
# 101                           :                           :
# 102  //www.historyartifacts.com  //www.historyartifacts.com
# 103                           .                           .
# 104                         did                         Did
# 105                         you                         you
# 106                        know                        know
# 107                           ?                           ?
# 108                         the                         The
# 109                          av                     average
# 110                        temp                 temperature
# 111                          in                          in
# 112                         new                         New
# 113                        york                        York
# 114                         has                          ha
# 115                         ris                       risen
# 116                          by                          by
# 117                       1.5°c                       1.5°C
# 118                        sint                       since
# 119                        1950                        1950
# 120                           .                           .
# 121                         thi                        This
# 122                        fact                        fact
# 123                           ,                           ,
# 124                       among                       among
# 125                         oth                      others
# 126                           ,                           ,
# 127                         was                          wa
# 128                   highlight                 highlighted
# 129                          in                          in
# 130                         the                         the
# 131                         rec                      recent
# 132                       study                       study
# 133                        publ                   published
# 134                          by                          by
# 135                         the                         the
# 136                     environ               Environmental
# 137                    research                    Research
# 138                    institut                   Institute
# 139                           ;                           ;
# 140                       howev                     however
# 141                           ,                           ,
# 142                         the                         the
# 143                       imply                 implication
# 144                          ar                         are
# 145                         yet                         yet
# 146                          to                          to
# 147                          be                          be
# 148                         ful                       fully
# 149                  understood                  understood
# 150                         ...                         ...
#
#                 lemmas_improved
# 0                           Dr.
# 1                         Smith
# 2                          ----
# 3                          ----
# 4                      renowned
# 5                     historian
# 6                          ----
# 7                          ----
# 8                         Ph.D.
# 9                          ----
# 10                      Harvard
# 11                         ----
# 12                          say
# 13                         ----
# 14                         ----
# 15                         ----
# 16                         20th
# 17                      century
# 18                         ----
# 19               transformative
# 20                         ----
# 21                         ----
# 22                         ----
# 23                   undeniable
# 24                         ----
# 25                         ----
# 26                          Mr.
# 27                      Johnson
# 28                         ----
# 29                          CEO
# 30                         ----
# 31              TechInnovations
# 32                         ----
# 33                        agree
# 34                         ----
# 35                         ----
# 36                         ----
# 37                         ----
# 38                        1990s
# 39                         ----
# 40                   technology
# 41                         ----
# 42                       impact
# 43                        begin
# 44                   accelerate
# 45                         ----
# 46                         ----
# 47                         ----
# 48                         ----
# 49                      discuss
# 50                         ----
# 51                         ----
# 52                        email
# 53                         ----
# 54                      contact
# 55                         ----
# 56          techinnovations.com
# 57                         ----
# 58                         ----
# 59                    emphasize
# 60                         ----
# 61                   importance
# 62                         ----
# 63                   innovation
# 64                         ----
# 65                    Meanwhile
# 66                         ----
# 67                          Ms.
# 68                        Davis
# 69                         ----
# 70                         ----
# 71                       expert
# 72                         ----
# 73                      ancient
# 74                      culture
# 75                         ----
# 76                         find
# 77                     artifact
# 78                        worth
# 79                         ----
# 80                    2,500,000
# 81                         ----
# 82                        Italy
# 83                         ----
# 84                Interestingly
# 85                         ----
# 86                         ----
# 87                    artifacts
# 88                         date
# 89                         back
# 90                         ----
# 91                          300
# 92                          B.C
# 93                         ----
# 94                        Visit
# 95                         ----
# 96                      website
# 97                         ----
# 98                         ----
# 99                         ----
# 100                        http
# 101                        ----
# 102  //www.historyartifacts.com
# 103                        ----
# 104                        ----
# 105                        ----
# 106                        know
# 107                        ----
# 108                        ----
# 109                     average
# 110                 temperature
# 111                        ----
# 112                         New
# 113                        York
# 114                        ----
# 115                        rise
# 116                        ----
# 117                       1.5°C
# 118                       since
# 119                        1950
# 120                        ----
# 121                        ----
# 122                        fact
# 123                        ----
# 124                       among
# 125                      others
# 126                        ----
# 127                        ----
# 128                   highlight
# 129                        ----
# 130                        ----
# 131                      recent
# 132                       study
# 133                     publish
# 134                        ----
# 135                        ----
# 136               Environmental
# 137                    Research
# 138                   Institute
# 139                        ----
# 140                     however
# 141                        ----
# 142                        ----
# 143                 implication
# 144                        ----
# 145                         yet
# 146                        ----
# 147                        ----
# 148                       fully
# 149                  understand
# 150                         ...
